# %%
import numpy as np
import math
from matplotlib import pyplot as plt
from scipy import stats
from pylab import rcParams
import re


##Homework for Phys 604
##Jan 21st
##A graphing file for my research that I made for Python 2. 
##Updated for Python 3 and implemented into jupyter notebook.

everything=[]

plt.rc('font', family='serif')

rcParams['figure.figsize']=8,6

mean=[]
median=[]
minimum=[]
maximum=[]
std=[]
allyears=[] 
inf=open('Desktop/Delta5/Deltas/D2years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears,ddof=1))
inf.close()
everything.extend(logyears)

inf=open('Desktop/Delta5/Deltas/D3years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears,ddof=1))
inf.close()
everything.extend(logyears)

inf=open('Desktop/Delta5/Deltas/D4years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears,ddof=1))
inf.close()
everything.extend(logyears)

inf=open('Desktop/Delta5/Deltas/D5years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears,ddof=1))
inf.close()
everything.extend(logyears)

inf=open('Desktop/Delta5/Deltas/D6years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears,ddof=1))
inf.close()
everything.extend(logyears)

inf=open('Desktop/Delta5/Deltas/D7years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears,ddof=1))
inf.close()
everything.extend(logyears)

inf=open('Desktop/Delta5/Deltas/D8years.txt','r')
lines=inf.readlines()
years=[]
for line in lines:
	div=re.split('\s+',line)
	year=div[2]
	years.append(float(year))
logyears=[]
for k in years:
	logers=math.log(k,10.0)
	logyears.append(logers)

mean.append(np.mean(logyears))
median.append(np.median(logyears))
minimum.append(min(logyears))
maximum.append(max(logyears))
std.append(np.std(logyears, ddof=1))
inf.close()
everything.extend(logyears)

sigplus=[]
sigminus=[]
for i in range(len(mean)):	
	sigplus.append(mean[i]+2*std[i])
	sigminus.append(mean[i]-2*std[i])

Deltas=[2,3,4,5,6,7,8]
plt.plot(Deltas,sigplus,marker='x',linestyle='None', mew=1.5,label='+2 SD',color='b')
plt.plot(Deltas,mean,marker='x',linestyle='None', mew=1.5, label='mean',color='k')
plt.plot(Deltas,sigminus,marker='x',linestyle='None', mew=1.5,label=u'\u2212'+'2 SD',color='r')

slope, intercept, r_value, p_value, std_err = stats.linregress(Deltas,mean)
x = np.arange(1.0,9.0,0.01)
y = slope*x+intercept
print(slope)
print(intercept)
print(r_value**2)
print(std_err)

numbers=[]
for i in range(1000):
	numbers.append(2)
for i in range(1000):
	numbers.append(3)
for i in range(1000):
	numbers.append(4)
for i in range(1000):
	numbers.append(5)
for i in range(1000):
	numbers.append(6)
for i in range(1000):
	numbers.append(7)
for i in range(1000):
	numbers.append(8)	

slope1, intercept1, r_value1, p_value1, std_err1 = stats.linregress(numbers,everything)
x1 = np.arange(1.0,9.0,0.01)
y1 = slope1*x1+intercept1
print(slope1)
print(intercept1)
print(r_value1**2)
print(std_err1)
plt.plot(x,y, color='k', alpha=0.8, label='Linear Regression')

#plt.plot([1.8,8.2],[-0.5,-0.5],color='k',lw=0.5)
#plt.plot([7.88964,7.88964],[-0.8,-0.2],color='m',label='MMR P1 P2')
#plt.plot([6.45025,6.45025],[-0.8,-0.2],color='m')
#plt.plot([4.72682,4.72682],[-0.8,-0.2],color='m')
#plt.plot([4.16996,4.16996],[-0.8,-0.2],color='m')
#plt.text(7.88964,-0.1,'4:5', fontsize=12)
#plt.text(6.45025,-0.1,'5:6', fontsize=12)
#plt.text(4.72682,-0.1,'7:8', fontsize=12)
#plt.text(4.16996,-0.1,'7:9', fontsize=12)

#plt.plot([7.17027,7.17027],[-0.7,-0.3],color='c',label='MMR P1 P3')
#plt.plot([5.09123,5.09123],[-0.7,-0.3],color='c')
#plt.plot([3.95027,3.95027],[-0.7,-0.3],color='c')
#plt.plot([3.22810,3.22810],[-0.7,-0.3],color='c')
#plt.plot([5.95301,5.95301],[-0.7,-0.3],color='c')
#plt.plot([2.72956,2.72956],[-0.7,-0.3],color='c')
#plt.plot([2.36458,2.36458],[-0.7,-0.3],color='c')
#plt.plot([4.44842,4.44842],[-0.7,-0.3],color='c')
#plt.plot([2.08578,2.08578],[-0.7,-0.3],color='c')

#plt.text(7.17027,-0.2,'2:3', fontsize=10)
#plt.text(5.09123,-0.2,'3:4', fontsize=10)
#plt.text(3.95027-0.03,-0.2,'4:5', fontsize=10)
#plt.text(3.22810,-0.2,'5:6', fontsize=10)
#plt.text(5.95301,-0.2,'5:7', fontsize=10)
#plt.text(2.72956,-0.2,'6:7', fontsize=10)
#plt.text(2.36458+0.03,-0.2,'7:8', fontsize=10)
#plt.text(4.44842+0.02,-0.2,'7:9', fontsize=10)
#plt.text(2.08578+0.01,-0.2,'8:9', fontsize=10)

m3=1.176
m5=0.765
y3=-1.663
y5=-0.030
mavg=(m3+m5)/2.0
yavg=(y3+y5)/2.0
c_corr=yavg+math.log(3.0/2.0*(2*10**-7.0/3.0)**(1.0/3.0),10.0)
yint=c_corr-math.log(3.0/2.0*(2*10**-5.0/3.0)**(1.0/3.0),10.0)


delta = np.arange(0., 10., 0.2)
plt.plot(delta, delta*mavg+yint,linestyle='--', dashes=(5,6), color='k',alpha=.7, label="Predicted using Chambers")

#plt.plot(x1,y1, color='k',linestyle='--')
plt.legend(loc=2,numpoints=1,fontsize=10)
plt.xlabel(r'$\Delta$'+' (mutual Hill radii)', fontsize=14)
plt.ylabel('log(years)', fontsize=14)
plt.axis([1.8,8.2,-1,8])
plt.tick_params(labelsize=12)
plt.show()
# Out:
# 1.10477157615
# -1.74799237316
# 0.983048966079
# 0.0648780833013
# 1.10477157615
# -1.74799237316
# 0.965815043246
# 0.00248459757858
